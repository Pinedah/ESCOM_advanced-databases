# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

mainpath = "/content/drive/My Drive/Colab Notebooks/Bases de Datos Avanzadas/Datasets"
# filename = "SSNMX_catalogo_20240101_20241231.csv"
filename2 = "SSNMX_catalogo_19000101_20250213.csv"
fullpath = os.path.join(mainpath, filename)
fullpath2 = os.path.join(mainpath, filename2)

data = pd.read_csv(fullpath)
# data2 = pd.read_csv(fullpath2)
# Out:
# Mounted at /content/drive

# %%
data.head()
# Out:
#         Fecha      Hora  Magnitud  Latitud  Longitud  Profundidad  \
# 0  01/01/2024  00:15:51       3.2  18.7483 -104.6020         16.5
# 1  01/01/2024  00:30:39       4.3  15.5482  -95.8245         16.1
# 2  01/01/2024  00:53:59       3.1  19.5943 -102.4950          5.3
# 3  01/01/2024  01:09:24       3.2  18.4185 -100.4230         55.4
# 4  01/01/2024  01:16:57       3.1  19.7267 -104.6570         54.0
#
#                     Referencia de localizacion   Fecha UTC  Hora UTC   Estatus
# 0         45 km al SUROESTE de MANZANILLO, COL  01/01/2024  06:15:51  revisado
# 1           41 km al SURESTE de CRUCECITA, OAX  01/01/2024  06:30:39  revisado
# 2  2 km al OESTE de LOS REYES DE SALGADO, MICH  01/01/2024  06:53:59  revisado
# 3            19 km al NOROESTE de ARCELIA, GRO  01/01/2024  07:09:24  revisado
# 4  27 km al NOROESTE de CASIMIRO CASTILLO, JAL  01/01/2024  07:16:57  revisado

# %%
data
